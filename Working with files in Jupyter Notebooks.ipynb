# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summerized.

# %% [markdown]
# <bold>Objectives:</bold>
#
# - List of popular languages that Data Scientist use
# - List of some common libraries used by Data Scientist
# - Examples of some arithmatic expression in Python
# - Examples of a mathematic expresssion in Python to convert 200 minutes into hours

# %% [markdown]
# Some of the popular languagees that Data Scientists used are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java

# %% [markdown]
# Some commonly used libraries used by Data Scientist include:
#
# 1. NumPy
# 2. Pandas
# 3. Seaborn
# 4. PyTorch
# 5. Matplotlib
# 6. TensorFlow

# %% [markdown]
# | Data Science Tools|
# |-------------------|
# |      Apache       |
# |-------------------|
# |      Spyder       |
# |-------------------|
# | Visual Studio Code|
# |-------------------|

# %% [markdown]
# ### Below are a few examples of evaluating arithmatic expressions in Python
#
# Addion:
# -------
# result = 5+3
# print(result)
#
# Multiplication:
# ---------------
# result = 4*7
# print(result)
#
# Division:
# ---------
# result = 9/3
# print(result)

# %%
# This will convert 200 minutes to hours by dividing by 60.

minutes = 200
conversion = minutes/60
hours = conversion
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Name: BINGKvN LvO
# 11/23/2025

# %%
# This is simple arithmatic expression to multiply then add integers.

result1 = 3*4
result2 = result1 + 5
print(result2)
# Out:
# 17
